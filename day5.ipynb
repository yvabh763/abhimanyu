# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
#pip install scikit-image
from skimage import  io #io module is used to read and write images
#photo=io.iread('york_minister.jpg')
#image = io.imread('E:\python\download.jpg)
photo = io.imread('IMG_20220208_131659.jpg')#read the image 
tytpe(photo)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 5
#       2 from skimage import  io #io module is used to read and write images
#       3 #photo=io.iread('york_minister.jpg')
#       4 #image = io.imread('E:\python\download.jpg)
# ----> 5 photo = io.imread(r'E:python\download.jpg' )#read the image
#       6 tytpe(photo)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\skimage\_shared\utils.py:328, in deprecate_parameter.__call__.<locals>.fixed_func(*args, **kwargs)
#     324     elif self.new_name is not None:
#     325         # Assign old value to new one
#     326         kwargs[self.new_name] = deprecated_value
# --> 328 return func(*args, **kwargs)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\skimage\io\_io.py:82, in imread(fname, as_gray, plugin, **plugin_args)
# ...

# %%
pip install scikit-image
# Out:
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/12.9 MB 9.5 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.9 MB 10.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.5/12.9 MB 9.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.3/12.9 MB 9.2 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.9 MB 9.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 9.2 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.9 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------- -------------- 1.3/2.0 MB 10.2 MB/s eta 0:00:01
# ...
